# %%
import pandas as pd
import numpy as np
import pickle
import joblib

# %%
df = pd.read_csv('TrainData_Processed.csv', index_col=[0])
df.head()
# Out:
#       Price    Levy  Prod. year  Leather interior  Engine volume   Mileage  \
# 0  9.497622  1399.0        2010                 0           3.41  186005.0
# 1  9.718422  1018.0        2011                 0           3.00  192000.0
# 2  9.043932     0.0        2006                 0           1.30  200000.0
# 3  8.190632   862.0        2011                 0           2.50  168966.0
# 4  9.369564   446.0        2014                 0           1.30   91901.0
#
#    Cylinders  Airbags  Turbo  Mileage_BIN  left wheel  right wheel  \
# 0        6.0       12      0          5.0           1            0
# 1        6.0        8      0          5.0           1            0
# 2        4.0        2      0          5.0           0            1
# 3        4.0        0      0          4.0           1            0
# 4        4.0        4      0          2.0           1            0
#
#    Manufacturer   Model  Category  Fuel type  Gear box type  Drive wheels  \
# 0          21.0  1137.0       4.0        2.0            0.0           0.0
# 1           5.0   597.0       4.0        5.0            2.0           0.0
# 2          14.0   630.0       3.0        5.0            3.0           1.0
# 3          11.0   603.0       4.0        2.0            0.0           0.0
# 4          14.0   630.0       3.0        5.0            0.0           1.0
#
#    Color
# 0   12.0
# 1    1.0
# 2    1.0
# 3   14.0
# 4   12.0

# %%
x = df.columns.tolist()

# %%
import AlgoData as alg

# %%
x,y = alg.ManufactUniqueModels()

# %%
x
# Out:
# {'lexus': array(['rx 450', 'rx 350', 'rx 400', 'gx 470', 'gx 460', 'nx 300',
#         'ct 200h', 'gs 350', 'nx 200', 'rx 300', 'rx 400 hybrid',
#         'hs 250h hybrid', 'es 350', 'is 200', 'es 300', 'is 250', 'ls 460',
#         'is 350', 'hs 250h', 'ct 200h f-sport', 'lx 570', 'lx 470',
#         'rx 450 h', 'ct 200h f sport', 'rc f', 'is 250 რესტაილინგი',
#         'rx 400 restailing', 'gx 470 470', 'is 300', 'gs 300',
#         'is 250 turbo', 'is-f', 'gs 450', 'rx 450 hybrid',
#         'gx 470 suv 4d (4.7l v8 s', 'rc f f sport', 'es 300 hybrid',
#         'is 350 c', 'ct 200h 1.8', 'rx 400 h', 'rx 450 f sport'],
#        dtype=object),
#  'chevrolet': array(['equinox', 'cruze lt', 'captiva', 'cruze', 'orlando', 'volt',
#         'avalanche', 'malibu', 'lacetti', 'aveo', 'matiz', 'spark',
#         'impala', 'cruze ltz', 'camaro', 'cruze strocna', 'volt premier',
#         'traverse', 'cruze premier', '1500', 'equinox lt', 'cruze rs',
#         'sonic', 'cruze ls', 'trailblazer', 'cruze sonic', 'nubira',
#         'cruze l t', 'malibu lt', 'malibu eco', 'hhr', 'suburban',
#         'cruze cruze', 'camaro ls', 'silverado', 'malibu hybrid', 'trax',
#         'volt full packet', 'sonic lt', 'corvette', 'niva', 'camaro rs',
#         'colorado', 'cruze lt rs', 'kalos', 'cruze s'], dtype=object),
#  'honda': array(['fit', 'civic', 'cr-v', 'hr-v ex', 'insight', 'stream', 'shuttle',
#         'element', 'odyssey', 'insight ex', 'hr-v', 'accord', 'fit sport',
#         'step wagon pada', 'civic ex', 'fit hbrid', 'passport', 'fit aria',
#         'fit s', 'inspire', 'fred', 'fit hibrid', 'pilot', 'elysion',
#         'accord cl9 type s', 'fit hybryd', 'fit fit', 'edix',
#         'elysion 3.0', 'civic ferio', 'cr-z', 'fit premiym', 'cr-v cr-v',
#         'fit rs modeli', 'cr-z ჰიბრიდი', 'fit rs', 'fred hibridi',
#         'fit rs mugen', 'crx', 'step wagon', 'edix fr-v', 'fit modulo',
#         'fit gp-5', 'fit "s"- paketi.', 'cr-v lx', 'fit ex', 'crossroad',
#         '400x', 'insight lx', 'fit gp-6', 'hr-v exl', 'fit hybrid',
#         'fit premiumi', 'crosstour', 'legend full', 'fit premium paketi',
#         'integra', 'step wagon rg2 spada', 'fit navi premium',
#         'civic hybrid', 'ridgeline', 'fit lx'], dtype=object),
#  'ford': array(['escape', 'transit', 'escape hybrid', 'fusion', 'mustang',
#         'focus se', 'explorer', 'c-max', 'fusion titanium', 'taurus',
#         'galaxy', 'fiesta', 'fiesta 1.6', 'focus', 'transit connect',
#         'tourneo connect', 'transit 350t', 'transit connect ბენზინი',
#         'edge', 'mondeo', 'escort', 'sierra', 'fusion phev',
#         'escape titanium', 'ranger', 'transit cl', 'escape 3.0',
#         'transit fff', 'transit s', 'c-max hybrid', 'transit 135',
#         'expedition', 'taurus interceptor', 'focus titanium', 'ka',
#         'focus st', 'maverick', 's-max', 'c-max sel', 'fusion se', 'b-max',
#         'focus fokusi', 'transit custom', 'focus flexfuel',
#         'transit connect prastoi', 'transit t330', 'escape se',
#         'escape მერკური მერინერი', 'ecosport se', 'f150', 'cougar',
#         'c-max c-max', 'c-max premium', 'mustang cabrio',
#         'transit tourneo', 'c-max se', 'transit 100ld',
#         'transit პერეგაროტკა', 'explorer turbo japan', 'fusion bybrid',
#         'fusion 2015', 'fusion hibrid', 'fiesta se', 'explorer xlt',
#         'fusion 1.6', 'transit ford', 'ecosport', 'mustang ecoboost',
#         'scorpio', 'fusion hybrid', 'courier', 'transit 2.4',
#         'sierra dizel', 'taurus x', 'ranger wildtrak', 'escape სასწრაფოდ',
#         'escape escape', 'focus sel', 'fusion hybrid se'], dtype=object),
#  'hyundai': array(['santa fe', 'sonata', 'elantra', 'h1', 'tucson', 'genesis',
#         'elantra sport limited', 'i30', 'veloster', 'sonata sport',
#         'elantra se', 'accent', 'grandeur', 'kona', 'ix35',
#         'elantra limited', 'sonata 2.0t', 'sonata s',
#         'sonata blue edition', 'sonata hybrid', 'elantra gt',
#         'santa fe ultimate', 'sonata hibrid', 'getz',
#         'elantra gls / limited', 'tucson turbo', 'ioniq', 'sonata lpg',
#         'ix35 2.0', 'veloster r-spec', 'azera', 'tucson limited',
#         'elantra 2014', 'lantra', 'sonata limited', 'tucson se',
#         'sonata 2.4l', 'lantra limited', 'veloster turbo', 'santa fe long',
#         'h1 grandstarex', 'h1 grand starex', 'accent se', 'elantra 2016',
#         'veloster remix', 'elantra limitedi', 'elantra i30',
#         'santa fe sport', 'sonata se limited', 'h1 starixs', 'accent gs',
#         'elantra gs', 'i20', 'i40', 'sonata se', 'veracruz', 'galloper',
#         'sonata სასწრაფოდ'], dtype=object),
#  'toyota': array(['prius', 'camry', 'chr', 'highlander', 'chr limited', 'tacoma',
#         'prius c', 'aqua', 'voxy', 'vitz', 'yaris', 'rav 4', 'sienna',
#         'vitz funkargo', 'camry se', 'rav 4 xle sport', 'sienta',
#         'avalon limited', 'ist', 'corolla', 'tundra', 'rav 4 le', 'avalon',
#         'rav 4 s p o r t', 'aqua s', 'land cruiser prado', 'corolla im',
#         'corolla verso', 'auris', 'fj cruiser', 'ipsum', 'corolla 04',
#         'prius 2014', 'aqua g soft leather sele', 'prius v', 'passo',
#         'isis', 'ist 1.5', 'harrier', 'sequoia', 'corolla le', 'camry s',
#         'ipsum s', 'prius plugin', 'verso', 'alphard', 'camry xle',
#         'venza', 'corolla s', 'altezza', 'estima', 'camry sport', 'hilux',
#         'caldina', 'hilux surf', 'prius c navigation', 'prius v alpina',
#         'highlander sport', 'aqua l paketi', 'avensis', 'prius s',
#         'will vs', 'prius blug-in', 'yaris ia', 'camry sporti',
#         'camry hybrid', 'camry le', 'fortuner', 'wish', 'vitz rs',
#         'century', 'fun cargo', 'aqua g klas', '4runner',
#         'highlander 2.4 lit', 'prius ფლაგინი', 'prius 1.5i', 'mark x',
#         'aqua g', 'camry sport se', 'highlander limited', 'corolla spacio',
#         'camry xv50', 'prius ჰიბრიდი', 'aqua hibrid', 'celica',
#         'rav 4 sport', 'prius tss limited', 'land cruiser', 'vitz i.ll',
#         'rav 4 xle', 'land cruiser prado rx', 'corolla eco', 'hiace',
#         '4runner limited', 'prius v hybrid', 'rav 4 limited', 'camry sel',
#         'belta', 'prius 9', 'yaris rs', 'camry xlei', 'prius 11',
#         'land cruiser 105', 'land cruiser 100', 'matrix xr', 'rav 4 se',
#         'prius plug-in', 'rav 4 dizel', 'prius personna',
#         'prius c ჰიბრიდი', 'noah', 'land cruiser 11', 'camry sport paket',
#         'will chypa', 'voxy 2003', 'ractis', 'aqua სასწრაფოდ',
#         'prius c 2013', 'sienta le', 'highlander 2,4',
#         'prius c 80 original', 'prius plug in', 'aqua sport', 'yaris se',
#         'land cruiser 200', 'highlander xle', 'prius 1.8', 'corolla se',
#         'prius c hybrid', 'prius prius', 'camry xse', 'land cruiser 80',
#         'prius plagin', 'prius 3', 'rav 4 l', 'bb', 'camry ჰიბრიდი',
#         'camry se hibryd', 'grand hiace', 'tacoma trd off road',
#         'corolla 140', 'rav 4 super!!!', 'cami', 'prius c yaris ia',
#         'prius c 1.5i', 'prius v hibrid', 'prius c aqua'], dtype=object),
#  'mercedes-benz': array(['e 350', 'e 220', 'vito', 'e 300', 'c 180', 'gla 250', 'a 160',
#         'ml 350', 'gl 63 amg', 'e 320', 'sprinter', 'e 500 amg', 'c 220',
#         '208', 'a 170', 'e 240 e 240', 'c 250', 'vaneo', 'cls 550',
#         'c 300', 'c 350', 'cls 500', 's 350', 'c 200', 'e 350 ამგ',
#         'clk 320', 'ml 250', 'e 200', 'gle 350', 'e 250', 'glc 300',
#         'c 240', 'e 240', 's 500 long', 'c 200 2.0', 'ml 550 4.7',
#         'clk 240', 'e 270', 'slk 230', 'e 230', 'gl 320', 'clk 320 amg',
#         's 550', 'sprinter 411', 'e 500', 's 550 ჰიბრიდი', 'cls 350',
#         'cla 250', 'gl 550', 'smart', 'a 190', 'sprinter max', 'a 140',
#         'e 280', 'gl 450', 'b 170', 'cls 55 amg', 'sprinter van',
#         'clk 430', 'viano', 'clk 200', 'e 550', '230', 'clk 230 .',
#         'c 280', 'e 430', 'r 350', 'ml 350 4 matic', 'clk 55 amg', 'c 230',
#         's 500', 'c 320 cdi', 'c 200 7g-tronic', 'ml 280 სასწრაფოდ', '320',
#         'cla 45 amg', 'c 36 amg', 'gle 63 amg', 'smart fortwo',
#         'cls 550 550', 'e 270 avangardi', 'e 350 212', 'e 55', 'ml 500',
#         'g 55 amg', 'ml 270', 'clk 200 kompressor', 'cls 350 amg',
#         'clk 270', '200', 'e 350 w211', 'ml 320', 'sprinter 315cdi',
#         'g 300', 'sprinter 311', 'e 280 cdi', 'e 36 amg', '311',
#         'vito 2.2', '416', 'e 300 avantgarde-ltd', '290', 'r 320',
#         'cl 550', 'e 350 amg', 'c 220 cdi', 's 320',
#         'e 350 4 matic amg packag', 'gl 320 bluetec', 'c 320', 'e 220 cdi',
#         'gl 350', 'g 320', 'cls 63 amg', 'r 350 bluetec', 's 350 longia',
#         'c 230 2.5', 'sprinter maxi-ს max', 'ml 350 bluetec', 'ml 270 cdi',
#         's 63 amg', 'c 200 kompressor', '300', 'ml 280', 'e 270 cdi',
#         'g 350', 'e 50', 'ml 350 3.7', 'c 400', 'glk 300', 'e 420', '270',
#         'c 250 luxury', 'e 320 4×4', 'g 550', 'glk 350', '190',
#         'c 300 4matic', 'c 250 1.8 ტურბო', 'a 140 140', 'e 400',
#         'ml 350 4matic', 'gl 350 bluetec', 'e 350 4 matic',
#         'sprinter vip class', 'clk 280', 'c 230 kompresor', 's 430',
#         'citan', 'clk 230', 'b 220', 'e 320 4matic', 's 55 5.5', 'gle 450',
#         'clk 200 200', '280', 'e 270 4', '250', 'ml 320 cdi', 'e 200 w210',
#         'gl 350 blutec', 'gl 450 3.0', 'c 250 a.m.g', 's 400', 'c 250 amg',
#         'c 180 komp', 'cl 500', '240', 'sprinter 313cdi', 'ml 350 370',
#         'c 180 2.0', 'e 320 bluetec', 'vito 115 cdi', '220',
#         'ml 350 ml350', 'a 200', 'cls 450 cls 400', 'g 63 amg',
#         'ml 350 sport', 'slk 32 amg', 'c 32 amg', 's 550 long',
#         'sprinter 316', 'sprinter 314', 'cls 350 japan', 'c 320 amg',
#         'e 220 w210...cdi', 's 600', 'glk 250', 'sprinter 316 cdi',
#         'ml 63 amg', 'ml 55 amg', 'sprinter 313', 'c 43 amg',
#         'vito long115', 'gl 350 დიზელი', 'vito 113', 'a 170 cdi',
#         'e 280 3.0', 'c 270', 'vito 111 cdi', 'ml 500 amg',
#         's 350 cdi 320', 'ml 300', 'b 200', 'c 240 w203', 'cla 250 amg',
#         'sprinter 516', 'clk 320 avangarde', 'gls 63 amg',
#         'sprinter 315cdi-xl', 'gl 500', 'gla 200', 'b 200 turbo',
#         'clk 200 kompresor', 'c 300 sport', 'g 230 2.2cdi', 'vito 111',
#         'sprinter 308 cdi', 'sprinter euro4', 'viano ambiente', 'b 180',
#         'c 250 1,8 turbo', 'c 63 amg', 'vito 115', 'c 250 amg-paket-1,8',
#         'b 170 b class', 's 430 4.3', 'e 220 211', 'sl 55 amg',
#         'c 250 1.8', 'e 220 elegance', 's 420', 'ml 350 special edition',
#         'e 260', 'clk 200 208', 'v 230', 'clk 350', 'b 170 edition one',
#         'e 290', 'c 230 2.0 kompresor', 'vito extra long',
#         'c 300 6.3 amg package', 'vito 110d', 'e 200 cgi', 'e 200 2000',
#         'cl 55 amg kompressor', 's 500 67', 'ml 320 amg', 'cl550 amg',
#         'a 170 avangard', 'ml 550', 'slk 350 300', 'vito exstralong',
#         'c 240 w 203', 'vito extralong', 'e 500 avg', 'cl 600',
#         'e 230 124'], dtype=object),
#  'opel': array(['vectra', 'astra g', 'zafira', 'vectra b', 'astra', 'combo',
#         'corsa', 'meriva', 'sintra', 'astra 1600', 'omega 1',
#         'astra bertone', 'combo 2001', 'astra h', 'agila', 'astra astra',
#         'omega b', 'corsa corsa', 'vectra c', 'omega', 'zafira b',
#         'combo tdi', 'tigra', 'astra td', 'astra ge', 'crossland x',
#         'astra suzuki mr wagon', 'frontera', 'vectra ბ', 'astra j',
#         'omega c', 'astra cng', 'astra gtc 1.9 turbo dies', 'monterey',
#         'frontera a b', 'vectra h', 'astra gi', 'vectra 1.6', 'combo 1700',
#         'astra a.h', 'insignia'], dtype=object),
#  'porsche': array(['cayenne', '911', 'panamera', 'panamera s', '911 meqanika',
#         'macan', 'cayman', 'cayenne s'], dtype=object),
#  'bmw': array(['x5', '535', '520 vanos', '428 sport line', '328', '325', '530',
#         '330', '318', '750', 'x6', '328 xdrive', '535 m paket', '520',
#         '525', '320', '528 i', 'm3', 'x5 x5', '114', '320 diesel',
#         '318 სასწრაფოდ', '335', '730 3.0', 'x5 m', '435', 'x6 m', '325 ci',
#         '428', 'x5 3.5', '320 m', '528', '316 i', '740', '120', '135',
#         '540 i', '650', '550', 'x5 xdrive', '535 i', '640 gran-coupe',
#         '523', '320 i', '316', '5.30e+62', 'x3', 'x5 e53', '435 cupe',
#         'm5 japan', 'x1', '130', 'x5 xdrive 35d', '320 gran turismo',
#         '535 twinturbo', '550 gt', 'x5 x-drive', '128 m tech', 'x3 3.5i',
#         '550 f10', '545', 'x5 4,4i', '320 2.2', '645 ci', '225', '525 i',
#         '320 2.0', '328 dizel', '320 320', '535 comfort-sport', '525 525',
#         'x5 3.0', '745 i', '735', '116', '328 sulev', 'm5', 'x1 28xdrive',
#         'x5 restilling', '335 335i', '750 4.8', 'x5 rest', 'x1 x-drive',
#         'x5 3.0i', '3.25e+48', '645', '3.20e+38', '535 diesel', 'x1 4x4',
#         '530 gt', 'm6', '325 i', 'i3', '328 drift car', '328 i', '630',
#         '745', '3.18e+38', '520 i', '525 ///m', '730', '318 m',
#         '318 რესტაილინგი', 'x3 sdrive', 'x5 japan', '535 535',
#         '550 m packet', '118', '118 2,0', '335 d', '535 xi', '640',
#         'x5 4.8is', 'x4', '525 tdi', 'x5 m packet', '420', 'm550',
#         '535 i xdrive', '323', '128', 'z4', '530 m', 'm4', '340',
#         'x6 germany', '318 318', '530 525i', 'x5 diesel',
#         '520 d xdrive luxury', '118 m-sport lci', 'x5 35d', '525 vanos',
#         '635', '7.30e+34', '335 m paket', 'x5 e70', 'x6 limited', '740 i',
#         '535 m', '335 ტურბო', '428 i', '650 450 hp', '530 i', '316 1995',
#         'z4 3,0 si', '325 xi', 'x5 sport', 'x6 40d', '528 3.0'],
#        dtype=object),
#  'jeep': array(['grand cherokee', 'wrangler', 'compass', 'cherokee', 'liberty',
#         'grand cherokee saiubileo', 'renegade', 'patriot',
#         'grand cherokee laredo', 'wrangler arb',
#         'grand cherokee special e', 'wrangler sport',
#         'patriot 70th anniversary', 'patriot latitude'], dtype=object),
#  'volkswagen': array(['jetta', 'passat', 'golf', 'sharan', 'gti', 'golf 4', 'vento',
#         'polo', 'jetta სპორტ', 'crafter', 'tiguan', 'golf 6', 'jetta gli',
#         'up', 'passat sel', 'cc r line', 'cc 2.0 t', 'touareg', 'golf tdi',
#         'passat r-line', 'caddy', 'new beetle', 'cc', 'jetta sel',
#         'passat se', 'touran', 'scirocco', 'jetta tdi', 't3', 'golf 2',
#         'golf 3', '1500,1600 schtufenheck', 'passat sport', 'jetta se',
#         'eos', 'golf gti', 'jetta 2.0', 'passat rlaini', 'phaeton',
#         'passat pasat', 'passat 2.0 tfsi', 'jetta sport', 'cc sport',
#         'lupo iaponuri', 'transporter', 'golf 1.8', 'routan sel',
#         't3 0000', 'jetta სასწაფოდ', 'passat b7', 'lupo', 'passat b5',
#         'polo gti 16v', 'bora', 'jetta sei', 'crafter 2.5 tdi',
#         'passat tdi sel', 'crafter 2,5tdi', 'passat tsi-se', 'caddy cadi',
#         'jetta s', 'jetta 2', 'golf golf 5', 'jetta hybrid',
#         'jetta 1.4 turbo', 't5', 'tiguan se'], dtype=object),
#  'audi': array(['q7', 'q5', '50', 'a6', 'a7', 'a4 premium', 'a4', 'q3', 'a5',
#         'a3 premium', 'a8', 'a4 s line', 'a4 premium plius', 'allroad',
#         'q5 s-line', '100', 'rs7', 'a3', 'q7 sport', 'a3 4x4', 'a6 с6',
#         'a4 b6', 'a6 universal', 'q5 prestige', 'a6 quattro', 'a4 b5',
#         'rs6', 's3', 'a4 s4', 'a4 b7', 'tt', 'a6 premium plus',
#         'allroad allroad', 'a5 sportback', 's6', 'a6 c7', 'a6 evropuli',
#         'a4 sline'], dtype=object),
#  'renault': array(['megane 1.5cdi', 'clio', 'laguna', 'twingo', 'scenic',
#         'megane gt line', 'megane', 'megane 19', 'kangoo', 'duster',
#         'captur qm3 samsung', 'kangoo waggon', 'megane 1.9cdi', 'megane 5',
#         'megane 1.9 cdi'], dtype=object),
#  'nissan': array(['juke', 'patrol', 'serena', 'maxima', 'pathfinder', 'patrol y60',
#         'altima', 'rogue', 'tiida', 'elgrand', 'x-trail', 'teana', 'march',
#         'rogue sport', 'rogue sl', 'frontier', 'versa', 'x-terra', 'note',
#         'tiida 2008', 'sentra', 'fuga', 'tiida axis', 'bluebird', 'micra',
#         'murano', 'skyline', 'wingroad', 'serena serea', 'x-trail x-trail',
#         'presage rider', 'quest 2016', 'kicks', 'x-trail gt', '100 nx',
#         'kicks sr', 'cefiro', 'march 231212', 'tiida 15 m', 'vanette',
#         'quest', 'juke nismo rs', 'march rafeet', 'armada', 'juke nismo',
#         'gloria', 'x-trail nissan x trail r', 'latio', '370z',
#         'x-trail nismo', 'pathfinder se', 'presage', 'navara',
#         'skyline 4wd', 'tiida latio', 'qashqai advance cvt', 'almera',
#         'rasheen', 'leaf', 'qashqai sport', 'moco', 'silvia', 'almera dci',
#         'skyline gt250', 'primera', 'lafesta', 'juke juke', 'terrano',
#         'micra <diesel>', 'juke turbo', 'versa s', 'versa se'],
#        dtype=object),
#  'subaru': array(['forester', 'legacy', 'outback', 'stella', 'xv',
#         'legacy b4 twin turbo', 'xv limited', 'impreza', 'brz',
#         'forester sh', 'impreza g4', 'crosstrek', 'forester stb',
#         'legacy bl5', 'forester xt', 'forester 4x4', 'forester crosssport',
#         'outback limited', 'forester cross sport', 'r2', 'legacy outback',
#         'legacy b4', 'xv hybrid', 'impreza sport', 'sambar', 'b9 tribeca',
#         'impreza wrx/sti limited', 'forester l.l.bean', 'outback 3.0',
#         'outback 2007'], dtype=object),
#  'daewoo': array(['lacetti', 'gentra', 'matiz'], dtype=object),
#  'kia': array(['picanto', 'carnival grand', 'cerato k3', 'optima', 'rio', 'soul',
#         'sorento', 'sportage', 'carnival', 'ceed', 'cadenza', 'cerato',
#         'rio lx', 'avella', 'forte', 'optima x', 'optima hybrid',
#         'sorento sx', 'optima eco', 'niro', 'sportage sx', 'sportage ex',
#         'optima ex', 'sorento ex', 'sportage prestige', 'optima sxl',
#         'carens', 'optima hybid', 'optima k5'], dtype=object),
#  'mitsubishi': array(['airtrek', 'lancer', 'pajero', 'delica', 'colt lancer',
#         'outlander', 'i', 'colt', 'pajero mini', 'pajero io', 'l 200',
#         'montero', 'outlander 2.0', 'minica', 'mirage', 'coltplus',
#         'grandis', 'rvr', 'outlander sport', 'outlander se',
#         'montero sport', 'carisma', 'eclipse', 'coltplus plus',
#         'outlander სპორტ', 'lancer gt', 'chariot', 'pajero montero',
#         'pajero 2.5diezel', 'outlander xl', 'pajero mini 2008 წლიანი',
#         'eclipse es', 'space runner', 'airtrek turbo', 'galant',
#         'galant gts', 'lancer gts', 'delica 5', 'pajero mini 2010 წლიანი'],
#        dtype=object),
#  'ssangyong': array(['korando', 'rexton', 'actyon', 'kyron', 'rexton super'],
#        dtype=object),
#  'mazda': array(['616', '1000', 'cx-7', 'mpv', '323', 'mazda 3', 'cx-9', '1300',
#         'mazda 3 sport', 'mx-5', 'atenza', 'premacy', 'demio', 'cx-5',
#         'mazda 6', 'mazda 6 touring', 'demio evropuli', 'eunos 500',
#         'demio 12', 'axela', 'cx-5 touring', 'verisa', 'verisa 2007',
#         'demio mazda2', 'demio sport', 'cx-3', 'millenia', 'rx-8',
#         'mazda 2', '626', 'mazda 6 grand touring', 'protege', 'tribute',
#         '323 f', 'tribute სასწრაფოდ', 'mpv lx', 'mazda 5'], dtype=object),
#  'gmc': array(['terrain', 'yukon', 'acadia', 'envoy'], dtype=object),
#  'fiat': array(['500', '500c lounge', '500 abarth', '500l long', 'cinquecento',
#         '500 sport', 'doblo', '500 turbo', '500c', '500 46 ml',
#         '500 lounge', 'panda', '500l', '500 s', '500 abarth ტურბო', '500x',
#         '500x lounge', 'seicento fiat 600', '500 sport panorama', 'punto'],
#        dtype=object),
#  'infiniti': array(['qx60', 'qx80', 'g20', 'fx35', 'ex37', 'jx35', 'fx45', 'ex35',
#         'qx56', 'm37', 'g37', 'q50 s red', 'g35 x', 'q45'], dtype=object),
#  'suzuki': array(['grand vitara', 'jimny', 'kizashi', 'swift', 'liana', 'xl7', 'sx4',
#         'samurai', 'vitara', 'aerio sx', 'cervo', 'kizashi sporti',
#         'escudo', 'vitara gl+', 'swift sport', 'ignis', 'alto lapin',
#         'xl7 limited', 'sj 413 samurai', 'jimny glx', 'hustler',
#         'every landy nissan seren'], dtype=object),
#  'acura': array(['tl', 'tlx', 'rdx', 'tsx', 'mdx'], dtype=object),
#  'lincoln': array(['navigator', 'town car', 'mkz', 'mkz hybrid', 'continental'],
#        dtype=object),
#  'vaz': array(['1111', '2107', '2106', '2121 (niva)', '2107 07', 'vesta', '2109',
#         '2101 01', '2105', '2103 03', '2111'], dtype=object),
#  'gaz': array(['32214', '24 10', '20', '3796', '24', '3110', '322173', '21 3.0',
#         '21', '31105'], dtype=object),
#  'land rover': array(['discovery', 'freelander', 'range rover', 'defender 90 cabrio',
#         'range rover evoque', 'land rover sport', 'discovery lr3',
#         'range rover vogue', 'range rover evoque 2.0',
#         'range rover evoque რესტა', 'discovery iv'], dtype=object),
#  'mini': array(['cooper', 'countryman', 'cooper s cabrio r56', 'countryman s',
#         'cooper s cabrio', 'cooper r50', 'countryman s turbo',
#         'countryman sport', 'one', 'cooper f-56', 'paceman',
#         'cooper clubman', 'cooper s'], dtype=object),
#  'dodge': array(['challenger', 'journey', 'dart limited', 'dart gt 2.4', 'ram',
#         'avenger', 'durango', 'caliber', 'ramcharger', 'caravan',
#         'intrepid', 'caliber sxt', 'dart', 'neon', 'ram 1500',
#         'caravan tradesman', 'charger rt', 'caliber journey'], dtype=object),
#  'chrysler': array(['200', 'pt cruiser', 'town and country', 'sebring', 'pacifica',
#         '300', '300 limited', 'pt cruiser pt cruiser', 'crossfire'],
#        dtype=object),
#  'jaguar': array(['xf', 'xj', 'f-type', 'e-pace', 'x-type', 'f-pace', 'daimler',
#         'xk', 's-type', 'xe'], dtype=object),
#  'skoda': array(['octavia', 'fabia', 'octavia scout', 'superb'], dtype=object),
#  'daihatsu': array(['terios', 'yrv', 'sirion', 'feroza', 'mira', 'move'], dtype=object),
#  'buick': array(['century', 'encore', 'enclave', 'regal'], dtype=object),
#  'cadillac': array(['allante', 'escalade', 'cts', 'srx', 'ats', 'catera', 'dts'],
#        dtype=object),
#  'peugeot': array(['206', '607', '207', '406', '307', '508', '3008', '807',
#         '3008 2.0', '206 cc', '407'], dtype=object),
#  'volvo': array(['c30 2010', 'xc90', '960', 's60', 'c70', 'xc90 3.2 awd', 's80',
#         's70', 's40', 'v50', '940', 'xc90 2.5turbo'], dtype=object),
#  'uaz': array(['31514', 'patriot', '31514 uaz'], dtype=object)}

# %%
y
# Out:
# ['lexus',
#  'chevrolet',
#  'honda',
#  'ford',
#  'hyundai',
#  'toyota',
#  'mercedes-benz',
#  'opel',
#  'porsche',
#  'bmw',
#  'jeep',
#  'volkswagen',
#  'audi',
#  'renault',
#  'nissan',
#  'subaru',
#  'daewoo',
#  'kia',
#  'mitsubishi',
#  'ssangyong',
#  'mazda',
#  'gmc',
#  'fiat',
#  'infiniti',
#  'suzuki',
#  'acura',
#  'lincoln',
#  'vaz',
#  'gaz',
#  'land rover',
#  'mini',
#  'dodge',
#  'chrysler',
#  'jaguar',
#  'skoda',
#  'daihatsu',
#  'buick',
#  'cadillac',
#  'peugeot',
#  'volvo',
#  'uaz']

# %% [markdown]
#  params['manufacturer'],
#
# params['model'],
#
# params['category'],
#
# params['fuel_type'],
#
# params['gear_box_type'],
#
# params['drive_wheels'],
#
# params['color']
