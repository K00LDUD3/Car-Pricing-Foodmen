# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Checking arrangement of columns

# %%
df_p = pd.read_csv('TrainData_Processed.csv', index_col=[0])
df_p.head()
# Out:
#       Price    Levy  Prod. year  Leather interior  Engine volume   Mileage  \
# 0  9.497622  1399.0        2010                 1           3.41  186005.0
# 1  9.718422  1018.0        2011                 0           3.00  192000.0
# 2  9.043932     0.0        2006                 0           1.30  200000.0
# 3  8.190632   862.0        2011                 1           2.50  168966.0
# 4  9.369564   446.0        2014                 1           1.30   91901.0
#
#    Cylinders  Airbags  Turbo  Mileage_BIN  EngineVolume_BIN  Manufacturer  \
# 0        6.0       12      0          5.0               4.0          21.0
# 1        6.0        8      0          5.0               4.0           5.0
# 2        4.0        2      0          5.0               0.0          14.0
# 3        4.0        0      0          4.0               3.0          11.0
# 4        4.0        4      0          2.0               0.0          14.0
#
# ...

# %%
df_r = pd.read_csv('TrainData_Raw.csv', index_col=[0])
df_r.head()
# Out:
#    Price    Levy Manufacturer    Model  Prod. year   Category  \
# 0  13328  1399.0        LEXUS   RX 450        2010       Jeep
# 1  16621  1018.0    CHEVROLET  Equinox        2011       Jeep
# 2   8467     0.0        HONDA      FIT        2006  Hatchback
# 3   3607   862.0         FORD   Escape        2011       Jeep
# 4  11726   446.0        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type  Engine volume   Mileage  Cylinders  \
# 0              Yes    Hybrid            3.5  186005.0        6.0
# 1               No    Petrol            3.0  192000.0        6.0
# 2               No    Petrol            1.3  200000.0        4.0
# 3              Yes    Hybrid            2.5  168966.0        4.0
# 4              Yes    Petrol            1.3   91901.0        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags  Turbo
# 0     Automatic          4x4  04-May        Left wheel  Silver       12      0
# ...
