# %%
import AlgoData_0_0_1 as alg
import pickle
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
filename = 'D:\\School\\2.CS\\2. Grd 12\Car-Pricing-Foodmen\\train.csv'
alg.ReadTrainData(filename=filename, raw=False)
# Out:
# (18707, 18)
#        index        ID      Price    Levy  Prod. year  Leather interior  \
# 0          0  45654403   9.497622  1399.0        2010                 1
# 1          1  44731507   9.718422  1018.0        2011                 0
# 2          2  45774419   9.043932     0.0        2006                 0
# 3          3  45769185   8.190632   862.0        2011                 1
# 4          4  45809263   9.369564   446.0        2014                 1
# ...      ...       ...        ...     ...         ...               ...
# 18702  19232  45798355   9.043932     0.0        1999                 1
# 18703  19233  45778856   9.660205   831.0        2011                 1
# 18704  19234  45804997  10.169997   836.0        2010                 1
# 18705  19235  45793526   8.581294  1288.0        2007                 1
# 18706  19236  45813273   6.152733   753.0        2012                 1
#
#        Engine volume   Mileage  Cylinders  Airbags  ...  EngineVolume_BIN  \
# 0               3.41  186005.0        6.0       12  ...               4.0
# 1               3.00  192000.0        6.0        8  ...               4.0
# 2               1.30  200000.0        4.0        2  ...               0.0
# 3               2.50  168966.0        4.0        0  ...               3.0
# 4               1.30   91901.0        4.0        4  ...               0.0
# ...              ...       ...        ...      ...  ...               ...
# 18702           2.00  300000.0        4.0        5  ...               2.0
# 18703           2.40  161600.0        4.0        8  ...               2.0
# 18704           2.00  116365.0        4.0        4  ...               2.0
# 18705           2.00   51258.0        4.0        4  ...               2.0
# 18706           2.40  186923.0        4.0       12  ...               2.0
#
#        Manufacturer   Model  Category  Fuel type  Gear box type  Drive wheels  \
# 0              21.0  1180.0       4.0        2.0            0.0           0.0
# 1               5.0   632.0       4.0        5.0            2.0           0.0
# 2              14.0   656.0       3.0        5.0            3.0           1.0
# 3              11.0   635.0       4.0        2.0            0.0           0.0
# 4              14.0   656.0       3.0        5.0            0.0           1.0
# ...             ...     ...       ...        ...            ...           ...
# 18702          24.0   362.0       1.0        0.0            1.0           2.0
# 18703          15.0  1267.0       9.0        5.0            2.0           1.0
# 18704          15.0  1373.0       4.0        1.0            0.0           1.0
# 18705           5.0   433.0       4.0        1.0            0.0           1.0
# 18706          15.0  1267.0       9.0        2.0            0.0           1.0
#
#        Doors  Wheel  Color
# 0        1.0    0.0   12.0
# 1        1.0    0.0    1.0
# 2        1.0    1.0    1.0
# 3        1.0    0.0   14.0
# 4        1.0    0.0   12.0
# ...      ...    ...    ...
# 18702    0.0    0.0   12.0
# 18703    1.0    0.0   11.0
# 18704    1.0    0.0    7.0
# 18705    1.0    0.0    1.0
# 18706    1.0    0.0   14.0
#
# [18707 rows x 22 columns]
